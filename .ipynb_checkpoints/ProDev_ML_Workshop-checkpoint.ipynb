# %% [markdown]
# # ProDev - ML Workshop

# %% [markdown]
# ## Descripción del Dataset

# %% [markdown]
# El Dataset fue tomado de la base de datos de la Universidad de Wisconsin [Diagnostic Wisconsin Breast Cancer Database](https://archive.ics.uci.edu/ml/datasets/Breast%2BCancer%2BWisconsin%2B%28Diagnostic%29). Este dataset describe las caracteristicas de las celulas de una variedad de tumores (En los bustos). Cada fila del dataset contiene las caraceteristicas de una celula y una etiqueta que lo clasifica como benigno o maligno.
#
# Con estos datos se desea desarrollar un sistema que utilize Machine Learning para determinar si un tumor es maligno o benigno a partir de las caracteristicas de sus celulas. Las técnicas utilizadas para la obtención de estas características van más allá del alcance de este tutorial.
#
# El dataset se compone de las siguientes variables:
#
# 1. Id
# 2. Diagnostico (M = Maligno, B = Benigno)
# 3. (3-32) Características de cada núcleo de la celula
#
# Se tienen las siguientes características de los núcleos de las celulas:
#
# * Radio
# * Textura
# * Perimetro
# * Área
# * Suavidad
# * Compactividad
# * Concavidad
# * Puntos de Concavidad
# * Simetria
# * Dimensión Fractal

# %% [markdown]
# ## Importar Librerias

# %%
import numpy as np # Algebra Lineal
import pandas as pd # Procesamiento y Lectura de datos

# Generar gráficos en un solo sitio como imágenes estáticas.
# %matplotlib inline 
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec # subplots
import mpld3 as mpl


#Import models from scikit learn module:
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %% [markdown]
# ## Cargar el Dataset

# %%
dataset = pd.read_csv("data.csv",header = 0)
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#       ...       texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0     ...               17.33           184.60      2019.0            0.1622
# 1     ...               23.41           158.80      1956.0            0.1238
# 2     ...               25.53           152.50      1709.0            0.1444
# 3     ...               26.50            98.87       567.7            0.2098
# 4     ...               16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Procesar el Dataset

# %% [markdown]
# En primer lugar vamos a remover las columnas que no necesitamos, ya que no aportan información acerca de la variable objetivo. Estas columnas son "id" y "Unnamed: 32".

# %%
dataset.drop('id',axis=1,inplace=True)
dataset.drop('Unnamed: 32',axis=1,inplace=True)

# Tamaño del Dataset
print dataset.shape
# Out:
# (569, 31)

# %% [markdown]
# Vamos a verificar cuantos valores puede tomar la variable "diagnosis" (Diagnostico), esto lo podemos hacer con el método unique de pandas, el cual retorna un array con los distintos valores que toma la columna del dataset.

# %%
dataset.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# Este resultado indica que solo hay dos posibles diagnósticos, Benigno o Maligno. Por lo tanto vamos a realizar una clasificación binaria. Los algoritmos de clasificación existentes solo manejan datos numericos, por lo cual tenemos que convertir los diagnosticos a un equivalente númerico. Ya que este solo toma dos valores vamos a usar 0 y 1 para identificar los diagnosticos (1 -> Maligno, 0 -> Benigno).

# %%
dataset['diagnosis'] = dataset['diagnosis'].map({'M':1,'B':0})
dataset.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# 0         0.2419           ...                    25.38          17.33
# 1         0.1812           ...                    24.99          23.41
# 2         0.2069           ...                    23.57          25.53
# 3         0.2597           ...                    14.91          26.50
# 4         0.1809           ...                    22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Exploración de los Datos

# %% [markdown]
# Es realmente fácil visualizar las características estadísticas de las variables cuantitativas del dataset, Pandas permite visulaizarlas fácilmente usando el método "describe".

# %%
dataset.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean           ...             radius_worst  texture_worst  \
# count     569.000000           ...               569.000000     569.000000
# mean        0.181162           ...                16.269190      25.677223
# std         0.027414           ...                 4.833242       6.146258
# min         0.106000           ...                 7.930000      12.020000
# 25%         0.161900           ...                13.010000      21.080000
# 50%         0.179200           ...                14.970000      25.410000
# 75%         0.195700           ...                18.790000      29.720000
# max         0.304000           ...                36.040000      49.540000
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        concavity_worst  concave points_worst  symmetry_worst  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        fractal_dimension_worst
# count               569.000000
# mean                  0.083946
# std                   0.018061
# min                   0.055040
# 25%                   0.071460
# 50%                   0.080040
# 75%                   0.092080
# max                   0.207500
#
# [8 rows x 31 columns]

# %% [markdown]
# También podemos generar un gráfico que nos permita ver la distribución del diagnostico de los tumores dentro del dataset.

# %%
plt.hist(dataset['diagnosis'])
plt.title('Diagnostico (M=1 , B=0)')
plt.show()

# %% [markdown]
# ### Relación entre Variables y Diagnostico

# %% [markdown]
# Para visualizar las relaciones entre variables y diagnostico, debemos separar el dataset en diagnosticos malignos y benignos para poder comparar.

# %%
features_mean=list(dataset.columns[1:11])
# split dataframe into two based on diagnosis
datasetM=dataset[dataset['diagnosis'] ==1]
datasetB=dataset[dataset['diagnosis'] ==0]

# %%
#Generar gráficos
plt.rcParams.update({'font.size': 8})
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(8,10))
axes = axes.ravel()
for idx,ax in enumerate(axes):
    ax.figure
    binwidth= (max(dataset[features_mean[idx]]) - min(dataset[features_mean[idx]]))/50
    ax.hist([datasetM[features_mean[idx]],datasetB[features_mean[idx]]], bins=np.arange(min(dataset[features_mean[idx]]), max(dataset[features_mean[idx]]) + binwidth, binwidth) , alpha=0.5,stacked=True, normed = True, label=['M','B'],color=['r','g'])
    ax.legend(loc='upper right')
    ax.set_title(features_mean[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# Observando los gráficos anteriores podemos concluir lo siguiente:
# 1. Los valores medios del radio celular, perimetro, área, compactividad, concavidad y puntos de concavidad pueden ser usados para la clasificación del cancer. Los valores más grandes de estas variables tienden a mostrar una correlación con los tumores malignos.
#
# 2. Los demás parámetros no muestran una relación clara en los histogramas como para considerarlos como predictores del diagnostico del tumor.

# %% [markdown]
# ## Crear el Dataset de Pruebas y Entrenamiento

# %% [markdown]
# Para crear estos datasets automáticamente podemos usar la utilidad *train_test_split* para separar el dataset en entrenamiento y pruebas. Vamos a usar el 75% del dataset para entrenamiento y el 25% para pruebas.

# %%
training, testing = train_test_split(dataset, test_size=0.3, random_state=2)

# %% [markdown]
# ## Método para entrenar y evaluar los modelos de clasificación

# %%
# Función para generar el modelo y evaluar su precisión
# Tomado de: https://www.analyticsvidhya.com/blog/2016/04/complete-tutorial-tree-based-modeling-scratch-in-python/
def classification_model(model, data, predictors, outcome):
  #Ajustar el modelo a los datos:
  model.fit(data[predictors],data[outcome])
  
  #Calcular predicciones en el dataset de entrenamiento:
  predictions = model.predict(data[predictors])
  
  #Imprimir la precisión del modelo
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print("Precisión : %s" % "{0:.3%}".format(accuracy))

  #Validar el modelo usando K-Fold Cross-validation
    
  kf = KFold(n_splits=5, shuffle=True, random_state=6)
  error = []
  for train, test in kf.split(data):
    # Seleccionar los datos de entrenamiento
    train_predictors = data[predictors].iloc[train,:]
    
    # Variable objetivo para el dataset de entrenamiento
    train_target = data[outcome].iloc[train]
    
    # Entrenar el modelo
    model.fit(train_predictors, train_target)
    
    #Guardar el error y el puntaje de validación cruzada
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
    
    print("Puntaje de Cross-Validation : %s" % "{0:.3%}".format(np.mean(error)))
    
  #Ajustar el modelo para usarlo fuera de la función:
  model.fit(data[predictors],data[outcome])

# %% [markdown]
# ## Regresión Logistica

# %% [markdown]
# La regresión logística resulta útil para los casos en los que se desea predecir la presencia o ausencia de una característica o resultado según los valores de un conjunto de predictores. Usando las variables que identificamos en la exploración de los datos, vamos a entrenar un modelo usando estos predictores.

# %%
predictor_var = ['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean']
outcome_var='diagnosis'
model_log=LogisticRegression()
classification_model(model_log,training,predictor_var,outcome_var)
# Out:
# Precisión : 88.442%
# Puntaje de Cross-Validation : 95.000%
# Puntaje de Cross-Validation : 90.625%
# Puntaje de Cross-Validation : 90.000%
# Puntaje de Cross-Validation : 89.019%
# Puntaje de Cross-Validation : 88.937%

# %%
coeff_df = pd.DataFrame(['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean'])
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(model_log.coef_[0])
coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#                Feature  Correlation
# 3     compactness_mean     0.873364
# 4  concave points_mean     0.589217
# 1       perimeter_mean     0.453961
# 2            area_mean     0.021801
# 0          radius_mean    -3.930303

# %% [markdown]
# ## Arbol de Decisión

# %% [markdown]
# Los algoritmos de aprendizaje basados en árboles se consideran de los mejores y más utilizados métodos de aprendizaje supervisado. Los métodos basados en árboles permiten crear modelos predictivos con alta precisión, estabilidad y facilidad de interpretación. A diferencia de los modelos lineales, las relaciones no lineales se mapean bastante bien. Son adaptables a la resolución de cualquier tipo de problema a la mano (clasificación o regresión)

# %%
predictor_var = ['radius_mean','perimeter_mean']
model_tree = DecisionTreeClassifier()
classification_model(model_tree,training,predictor_var,outcome_var)
# Out:
# Precisión : 100.000%
# Puntaje de Cross-Validation : 88.750%
# Puntaje de Cross-Validation : 85.625%
# Puntaje de Cross-Validation : 85.833%
# Puntaje de Cross-Validation : 85.894%
# Puntaje de Cross-Validation : 84.918%

# %% [markdown]
# ## Random Forest

# %% [markdown]
# **Random forest** también conocido en como '"Bosques Aleatorios"' es una combinación de árboles de decisión independientes entre sí. Este construye una larga colección de árboles de decisión no correlacionados y luego los promedia.

# %%
predictor_var = features_mean
model_forest = RandomForestClassifier(n_estimators=300, min_samples_split=30, max_depth=8, max_features=6)
classification_model(model_forest,training,predictor_var,outcome_var)
# Out:
# Precisión : 96.231%
# Puntaje de Cross-Validation : 100.000%
# Puntaje de Cross-Validation : 93.750%
# Puntaje de Cross-Validation : 93.333%
# Puntaje de Cross-Validation : 93.418%
# Puntaje de Cross-Validation : 92.709%

# %%
# Tunning Parameters
n_estimators = [100, 200, 300]
max_depth = [7, 8, 9]
min_samples_split = [20, 30, 40]
max_features=[2, 4, 6, 8]
param_grid = dict(n_estimators=n_estimators, min_samples_split=min_samples_split, max_depth=max_depth, max_features=max_features)
kfold = KFold(n_splits=5, shuffle=True, random_state=2)
grid_search = GridSearchCV(model_forest, param_grid, scoring="accuracy", n_jobs=8, cv=kfold)
grid_result = grid_search.fit(training[predictor_var], training[outcome_var])

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.947236 using {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 8}
# 0.937186 (0.026552) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 7}
# 0.934673 (0.029226) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 7}
# 0.934673 (0.026910) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 7}
# 0.939698 (0.026873) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 7}
# 0.939698 (0.024334) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 7}
# 0.942211 (0.023404) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 7}
# 0.937186 (0.022614) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 7}
# 0.939698 (0.021700) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 7}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.022614) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 7}
# 0.937186 (0.022614) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 7}
# 0.939698 (0.021700) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 7}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 7}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 7}
# 0.944724 (0.017133) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.013733) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 7}
# 0.939698 (0.014820) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 7}
# 0.939698 (0.024334) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 7}
# 0.937186 (0.020973) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.017849) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 7}
# 0.939698 (0.014820) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 7}
# 0.939698 (0.021700) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 7}
# 0.934673 (0.029062) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 7}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 7}
# 0.939698 (0.021700) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 7}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 7}
# 0.934673 (0.029226) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 8}
# 0.944724 (0.020580) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 8}
# 0.939698 (0.024334) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 8}
# 0.939698 (0.023007) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 8}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 8}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 8}
# 0.932161 (0.021977) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 8}
# 0.932161 (0.023380) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 8}
# 0.932161 (0.027192) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 8}
# 0.932161 (0.023175) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 8}
# 0.944724 (0.017133) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 8}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 8}
# 0.937186 (0.025153) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 8}
# 0.937186 (0.022614) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 8}
# 0.939698 (0.021700) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 8}
# 0.937186 (0.023980) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 8}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 8}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 8}
# 0.942211 (0.020439) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 8}
# 0.939698 (0.021700) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 8}
# 0.934673 (0.014713) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 8}
# 0.934673 (0.018378) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 8}
# 0.939698 (0.014820) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 8}
# 0.947236 (0.016696) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 8}
# 0.939698 (0.021700) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 8}
# 0.937186 (0.017849) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 8}
# 0.937186 (0.017849) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 8}
# 0.937186 (0.017849) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 8}
# 0.932161 (0.025828) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 8}
# 0.932161 (0.025828) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 8}
# 0.932161 (0.025828) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 8}
# 0.939698 (0.021700) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 8}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 8}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 8}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 8}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 8}
# 0.939698 (0.024334) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 9}
# 0.934673 (0.018614) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 9}
# 0.932161 (0.027192) with: {'max_features': 2, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 9}
# 0.934673 (0.025701) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 9}
# 0.939698 (0.016676) with: {'max_features': 2, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 9}
# 0.934673 (0.021627) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 9}
# 0.929648 (0.023436) with: {'max_features': 2, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 9}
# 0.939698 (0.024334) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 9}
# 0.939698 (0.024334) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 9}
# 0.942211 (0.020439) with: {'max_features': 4, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 9}
# 0.937186 (0.022614) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 9}
# 0.937186 (0.023980) with: {'max_features': 4, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 9}
# 0.934673 (0.027021) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 9}
# 0.939698 (0.021700) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 4, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 9}
# 0.944724 (0.020386) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 9}
# 0.939698 (0.021700) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 9}
# 0.942211 (0.018956) with: {'max_features': 6, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 9}
# 0.934673 (0.021627) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 9}
# 0.939698 (0.014820) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 9}
# 0.942211 (0.018956) with: {'max_features': 6, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 9}
# 0.944724 (0.017133) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 9}
# 0.942211 (0.018956) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 9}
# 0.942211 (0.018956) with: {'max_features': 6, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 9}
# 0.942211 (0.028189) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 100, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 200, 'max_depth': 9}
# 0.937186 (0.020973) with: {'max_features': 8, 'min_samples_split': 20, 'n_estimators': 300, 'max_depth': 9}
# 0.939698 (0.024334) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 100, 'max_depth': 9}
# 0.937186 (0.025153) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 200, 'max_depth': 9}
# 0.934673 (0.029062) with: {'max_features': 8, 'min_samples_split': 30, 'n_estimators': 300, 'max_depth': 9}
# 0.934673 (0.029062) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 100, 'max_depth': 9}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 200, 'max_depth': 9}
# 0.934673 (0.021627) with: {'max_features': 8, 'min_samples_split': 40, 'n_estimators': 300, 'max_depth': 9}
